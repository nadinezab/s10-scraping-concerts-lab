# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
# Import libraries
import re
import requests
from bs4 import BeautifulSoup

# %%
# Load html page using requests and pass to Beautifulsoup
url = 'https://www.residentadvisor.net/events'
html_page = requests.get(url)
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
# find area with data - middle column with event listings
relevantdata = soup.find('div', class_='fl col4')

# %%
#Narrow it down - pick up each event entry

entries = relevantdata.findAll('article')
entries[:2]
# Out:
# [<article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1381691#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2020-02-24T00:00" itemprop="startDate">2020-02-24T00:00</time></span><a href="/events/1381691"><img height="76" src="/images/listing-default.gif" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1381691" itemprop="url" title="Event details of Play London Every Monday">Play London Every Monday</a> <span>at <a href="/club.aspx?id=33592">XOYO</a></span></h1><div class="grey event-lineup">DJ GLENN D</div><p class="attending"><span>3</span> Attending</p></div></article>,
#  <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1380682#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2020-02-24T00:00" itemprop="startDate">2020-02-24T00:00</time></span><a href="/events/1380682"><img height="76" src="/images/events/flyer/2020/2/uk-0224-1380682-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1380682" itemprop="url" title="Event details of Desire Magic Mondays">Desire Magic Mondays</a> <span>at <a href="/club.aspx?id=170808">Union Club, Vauxhall</a></span></h1><div class="grey event-lineup">DUDA, Jefferson Souza, G Belmonte, Sofi Canter, Duwat?</div><p class="attending"><span>3</span> Attending</p></div></article>]

# %%
#getting first event name
print(entries[0].find('h1').find('a').text)

#getting all events name in a list
alleventnames = [entries.find('h1').find('a').text for entries in relevantdata.findAll('article')]
print(alleventnames[:5])
print(len(alleventnames))
# Out:
# Play London Every Monday
# ['Play London Every Monday', 'Desire Magic Mondays', 'London DJ School (DJ Lessons)', 'Kandy Mondays (£2 Drinks) at The Roxy', 'SCJ! Jam Night and Networking Event']
# 253

# %%
# define function to retrieve event names
def get_eventnames(soup):
    relevantdata = soup.find('div', class_='fl col4')
    entries = relevantdata.findAll('article')
    eventnames = [entries.find('h1').find('a').text for entries in relevantdata.findAll('article')]
    return eventnames

# %%
get_eventnames(soup)
# Out:
# ['Play London Every Monday',
#  'Desire Magic Mondays',
#  'London DJ School (DJ Lessons)',
#  'Kandy Mondays (£2 Drinks) at The Roxy',
#  'SCJ! Jam Night and Networking Event',
#  'Mobile Mondays',
#  'Paradox presents Tuesday Madness',
#  'Synergy: Back 2 Back',
#  'Pancake Rave at Ministry of Sound',
#  'Play London Every Monday',
#  'Brazilian Carnival Party',
#  'CDR London with Emmavie',
#  'Sneak Tuesdays at Xoyo (£3 Drinks)',
#  'Dirt',
#  'Mobile Mondays',
#  'F.M.G',
#  'Soul In Motion - Wed Feb 26th',
#  'Play London Every Monday',
#  'Final Cut: Midweek Party - R&B, Charts, House and More',
#  'FAT Action',
#  'Carl Michael VON Hausswolff / Zachary Paul / Tears|OV',
#  'The Beat Bangs',
#  'Alex Bradley',
#  'Pretend Residency',
#  '100 Wardour St Originals presents Louisa',
#  'SIN BIN Every Wednesday at Loop Bar',
#  'Millies Lounge at The Ned',
#  'GLO Thursday',
#  'No Static / Automatic Label Launch with Radioactive Man, Sync 24, Ara-u',
#  'Disco Teq: UKG Special',
#  'Algo Mas Every Thursday Night/Friday Morning',
#  'Mxlx // Tara Clerkin Trio // Genghis Cohn',
#  'Eat Your Own Ears presents Cashmere Cat',
#  'RS present: The Floor is Yours Workshop',
#  'Play London Every Monday',
#  'Herobust',
#  'GNG',
#  "Andy Warhol's Screen Tests Reel #10 + new soundtrack by Leif",
#  'S.S.G',
#  'TND 2020 Opening Party, new Location, new Journey Begin',
#  'Veritate',
#  'Wah Wah 45s',
#  'Carl Michael VON Hausswolff / Zachary Paul / Tears|OV',
#  'Throwback Thursdays at Piccadilly Institute',
#  'All the Days and Nights',
#  'Vitamin Social',
#  'Eclectic Lounge with Josh Rawl & Sami Dilla',
#  "Ólafur Arnalds 're:member' Album Listening Session in the Dark",
#  'Nuestra Casa',
#  'Hip Hop Karaoke at Queen of Hoxton',
#  'Peter Zummo Military Genius',
#  '100 Wardour St Originals presents Louisa',
#  'Isac Curtis - Underground Sound presents',
#  'FABRICLIVE: Planet V, 20 Years of Aerosoul vs Junglist Movement & Wxmb 2',
#  'Habibi Funk + Mehmet Aslan + Guedra Guedra',
#  'Reinier Zonneveld - London',
#  'Dusky, Fabio & Grooverider, Randall (Acid set), Jossy Mitsu & Make Me',
#  'Jeremy Underground & DJ Deep',
#  '[Sold Out] - Tinlicker & Guests',
#  'THEM XII - Pinch, Ansome, Headless Horseman, Sunil Sharpe',
#  "Fridays at EGG: Ilario Alicante, Margherita D'agui & Kyle E",
#  'Moxie - All Night Long - Sold Out',
#  "Livin' Proof",
#  'The Abba vs Fleetwood Mac Disco Party',
#  'Terrarium with Auntie Flo & Alexander Nut',
#  'South Circular II',
#  'Shkoon',
#  'Krafty Kuts & A. Skillz',
#  'Alison Wonderland - E1 - Fri 28th Feb',
#  'Ben Pearce presents: Renegades',
#  'Universe Seven: KRN, Sohrab, Matthew Neequaye',
#  'LBM x Menagerie x GFS - Charity Fundraver',
#  'Wavey Garms:Klose One, Doc Scott, Ray Keith, FAUZIA, Iona, Ok Williams',
#  'Hyve w. Per Hammar (Infuse/Dirty Hands), Le Louche & More',
#  'Mind Of Ours: Bermondsey',
#  "Off Supply with Montif Clare, Harry Rankin, Subaltune & Ella L'etang",
#  'Loose Lips with Umfang (Ninja Tune, Discwoman), Rommek & More',
#  'Concrete Music X Fruit Factory: Peckham Dance Party',
#  'Afrotized a Night of Pure Afrohouse',
#  'Sinai Sessions - London - Fox & Firkin',
#  'Concrete Lates: Plaid + Kelly Lee Owens (DJ)',
#  'Solis present: Othersounds with Central & DJ Sports (4HR Set)',
#  'S.C.D.D. Hazmat Team + Maruwa [Russia]',
#  'Silverlining Dubs in the Pub (i)',
#  'Mind Dance - Warehouse Party with Bok Bok & More',
#  'Should Know Better',
#  'jängäli',
#  'Play London Every Monday',
#  'The Secret DJ presents The Dark Room',
#  'Holler Back - Hiphop n R&B',
#  'The 3rd Estate - Live In The Lounge (Night 1)',
#  'Phase: Roni Size',
#  'Bashment Rave - Shoreditch Party',
#  'Bashment Skin Out - Camden Party',
#  'Number 90 presents Rhythm Sister',
#  'Karma: Arcadia Loungebar with Francis, Joe Ellis and More',
#  'Soba VI with Moody Food',
#  'The Gallery: Paul Oakenfold & ATB',
#  'Hedkandi 2020 London Launch',
#  'Treehouse',
#  'Femmme Fraiche #027 w. Hannah Holland, Marie Malarie, Lucia Blayke',
#  'Mad Hatters Club',
#  'Supa Dupa Fly x Brixton with Shortee Blitz (Kiss)',
#  'Young Echo OTO Takeover',
#  'Mansion Dance',
#  'Cascada Live',
#  'Valeron',
#  'Antics',
#  'Tropical Traffic',
#  'Interlude x Diffrent Music - Free Entry',
#  'Johnny Cash Converters + DJ Madmax',
#  'Student Night at Cafe de Paris Every Friday',
#  'Wealdstone Techno Collective presents: The Sanctuary 2020 Pt.1',
#  'Bashment vs Afrobeats - VIP Edition',
#  'Soca vs Dancehall - VIP Party',
#  'Pete BBE & Friends',
#  'Fire Bar Fridays',
#  'Elle Yaya - Underground Sound presents',
#  'Enclave Records presents (London)',
#  "Players Ball - London's Hypest Rap R&B Party",
#  'Wildlife!',
#  'Isac Curtis - Underground Sound presents',
#  'j.b. Glazer / Hyperdawn / Bunny Hoova',
#  'Soul Fever',
#  'Legpuppy & Friends',
#  'Disco Bits',
#  'Wonderland: Wonderhoots VOL: 3',
#  'Alex P @Reds Bar',
#  'Industry Fridays',
#  'Lovefingers - All Night Long in London',
#  'Space Ibiza 2020 Opening Party',
#  'ANTS',
#  'LWE presents Sphere 003',
#  'LoveJuice presents Repeat',
#  '10 Years of Neighbourhood at FOLD // 29.02.20 // DVS1, Freddy K, Grain, Cadans, Alienata +Tasha',
#  'Good Morning Midnight W/ Alvaro AM (Desolat) & Davina Moss (Hot Creations)',
#  'Collisions: Craig Richards B2B Binh, Margaret Dygas & DJ Bone',
#  "Honey Dijon Pres. 'Hidden Treasures' with Rhythm Section - Sold Out",
#  'ANTS After Party',
#  'Eclair Fifi - All Night Long',
#  "Club Mick's: Ivan Smagghe & Orpheu The Wizard (3 Hour Sets)",
#  'The South London Soul Train with The Mighty Mocambos (Live) - More',
#  '[SOLD OUT] Jack Your Body LDN - Road to Ibiza Part 1',
#  'The Big Disco with Greg Wilson',
#  'KAOS presents Rrose',
#  'Syzygy: First Birthday with Cosmjn, Fabe, Oden & Fatzo ',
#  'Up On The Roof x FUNK ME with Mousse T.',
#  'Groove Odyssey: Dimitri From Paris',
#  'DEEP MEDi at Corsica',
#  'Live at Robert Johnson [London]: Fort Romeau',
#  'Apogee // Sleeparchive (Live)',
#  'Crowded 003 with Miky J (Snatch! Records)',
#  'Deptford Northern Soul Club',
#  'Spiritland By Night: Detroit Swindle',
#  'Soul City: Disco, House & Soul Every Saturday',
#  'The Funk Soul Disco // Another Day to Disco',
#  'therefore Ahoy',
#  'Mantra: Every Saturday at Phonox',
#  'Rhythm n Funk x House Warming Malta Launch & Send Off Party',
#  '90 Goes Late with Ransom Note',
#  'Free Movements: Making-With',
#  'Love Carnival x Samedia Shebeen',
#  'Bill Brewster Does Disco',
#  'Creature Comforts with Facta (Wisdom Teeth / Livity Sound), R.O.S.H (Noviton), O.S Residents',
#  'Krautrock karaoke 7th Anniversary Event with Damo Suzuki',
#  'Resonate LDN presents Red or Dead',
#  'Sc&p: Die Selektion (Live) + Harry James + Night Terrors',
#  'Back 2 da old Skool presents... Reunion',
#  'Pleasurehood. Every Saturday at XOYO',
#  'Lick The Lid with Luc Mast',
#  'Five Miles x Meda Fury',
#  'Tom Middleton presents Global Communication Feat. Ross Sampson & The Epic String Quartet',
#  "Casamara presents, Joshua's House",
#  'Company. 3rd Birthday',
#  'NorthSouth Showcase',
#  'East Ends Every Saturday Morning',
#  'EGG LDN Pres Ibiza Workers Party - Tania Vulcano, Manu Gonzalez, Frank Storm, Luther Vine',
#  'Elevator East 3rd Birthday x Secret Party with TBC',
#  'The Zoo Project Ibiza - Essex',
#  'illumiNaughty Pres: Tokyo Rising',
#  'DEFINITI[ON] House Party w. Montana Cruz & Special Guest',
#  'Shoreditch Groove',
#  'Kiss: A Night of Prince',
#  'Hip Hop Soul x Ladies DJ Takeover',
#  'Peckham Soul 1ST Birthday Party',
#  '100% Hip-Hop',
#  'Has It Come To This w / Hatcha (UKG Set) + Scott Garcia',
#  'The Filthy Six - Filthy Business',
#  "SIP 'N Stroke (Urban Paint Party) (4pm-7pm)",
#  "SIP 'N Stroke (Paint Party) 8pm to 11pm",
#  'Metropolis Does Disco - Every Saturday',
#  'Vocal House Brunch',
#  'Wrong! Friday Night Afterhours',
#  'Locomotive Disco: The London Disco Society 8th Birthday',
#  'Astoria',
#  'The 3rd Estate - Live In The Lounge (Night 2)',
#  'Phase: Josh Butler',
#  'Rockers LDN x Trojan Records: Official Reggae Month Closing Party',
#  'TSA All Day w Special Guest TBA, Kurse D, Scott Kemp, More',
#  'Comedy Brunch - 29th February',
#  'Bashment Arena - 5AM Finish Party',
#  'Bootylicious at Union ft Afroswagg',
#  'Paragon - Free Day Party',
#  'Garage Proud',
#  'Ravenswood for Eat Or Heat 2020',
#  'Fiasco! 005 with Alexis, Caroline Lethô & Mr. Redley',
#  'Fire in Her Eyes - Underground Sound presents',
#  'Young Echo OTO Takeover',
#  'Towards Collapse Takeover at Chaos Theory 10 Years of Chaos Festival',
#  'WAH WAH',
#  'Porridge 15 Hour Warehouse Party // Green House Hackney Wick',
#  '·• Still Life •· Fabe · Oden & Fatzo Live · Manalou · Mabbam · Reis',
#  'Elle Yaya - Underground Sound presents',
#  "Don't You Want Me Baby",
#  'Cantaloop + DJ Miles Metric',
#  'Blaffirmative x Kupid - FHP',
#  'Student Night at Cafe de Paris Every Saturday',
#  'Electric Dreams (80s Alternative / Electronica)',
#  'Supernatural: New Concept Event',
#  'Drip or Drown - Hip Hop, Bashment, Afrobeats',
#  'Turn Up Shoreditch - Hiphop, Afrobeats, Bashment',
#  'Roads 30: Vibes From The Tr13e',
#  'FOQL & Astma (Live) with Visuals by Copy Corpo',
#  'The BIG Balkan Bash',
#  'Fourth Sounds',
#  'Khonsu',
#  'I Love the 80s vs 90s',
#  'Susu Laroche - A Blunt Instrument EP Launch',
#  'SES X 139 Artspace with Richie Littler and Feel-X',
#  'Remedy - Rap R&B Dancehall Afrobeats - Late Night Special',
#  'House Fusion',
#  'It Ddnt Happn',
#  'SiN',
#  'Burner Brunch: Leap Day Multiverse Madness',
#  'Brazilian Wax XXL',
#  'Goodbye Synapse || Quantum Leap',
#  'ABODE 2020 Welcome Back Party',
#  'Eastenderz - London (East End Dubs 6hr Set!)',
#  'fabric: Kruder & Dorfmeister (All Day Long)',
#  'Neverdogs presents: Bamboleo London',
#  'Our House - House & Techno Sunday',
#  'Sundays at fabric: Traumer (All Night Long)',
#  "Jaded Rave Edition III Ethan Fawkes, Melissa D'lima & More",
#  'Glamorous',
#  'Minimal Force Pres. Emex (Free Techno Sunday)',
#  'Sub Luv with Special Secret Guests',
#  '24h Pleasureboat with Triptil & Secret Guest(Acmé) & More',
#  'Our House - Night Afterparty',
#  'Lime - Every Sunday Morning',
#  'Sunday Selections with Jack Sellen',
#  'Loose Trax 6',
#  'Blaffirmative x Kupid - FHP',
#  'Monkeys ']

# %%
# getting first event date
entries[0].find('time').text.split('T')[0]
# Out:
# '2020-02-24'

# %%
# get all dates
alldates = [entries.find('time').text.split('T')[0] for entries in relevantdata.findAll('article')]
print(alldates[:5])
print(len(alldates))
# Out:
# ['2020-02-24', '2020-02-24', '2020-02-24', '2020-02-24', '2020-02-24']
# 253

# %%
def get_eventdates(soup):
    relevantdata = soup.find('div', class_='fl col4')
    entries = relevantdata.findAll('article')
    eventdates = [entries.find('time').text.split('T')[0] for entries in relevantdata.findAll('article')]
    return eventdates

# %%
get_eventdates(soup)
# Out:
# ['2020-02-24',
#  '2020-02-24',
#  '2020-02-24',
#  '2020-02-24',
#  '2020-02-24',
#  '2020-02-24',
#  '2020-02-25',
#  '2020-02-25',
#  '2020-02-25',
#  '2020-02-25',
#  '2020-02-25',
#  '2020-02-25',
#  '2020-02-25',
#  '2020-02-25',
#  '2020-02-25',
#  '2020-02-26',
#  '2020-02-26',
#  '2020-02-26',
#  '2020-02-26',
#  '2020-02-26',
#  '2020-02-26',
#  '2020-02-26',
#  '2020-02-26',
#  '2020-02-26',
#  '2020-02-26',
#  '2020-02-26',
#  '2020-02-26',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-27',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-28',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-02-29',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01',
#  '2020-03-01']

# %%
#get all venues in a list
alleventvenues = []
    
for entries in relevantdata.findAll('article'):
    try:
        alleventvenues.append(entries.find('h1').find('span').find('a').text)
    
    except:
        alleventvenues.append('none')

# %%
alleventvenues[:5]
# Out:
# ['XOYO', 'Union Club, Vauxhall', 'The Cause', 'The Roxy', 'Spice Of Life']

# %%
len(alleventvenues)
# Out:
# 253

# %%
def get_eventvenues(soup):
    relevantdata = soup.find('div', class_='fl col4')
    entries = relevantdata.findAll('article')
    eventvenues = []
    for entries in relevantdata.findAll('article'):
        try:
            eventvenues.append(entries.find('h1').find('span').find('a').text)
        except:
            eventvenues.append('none')
    return eventvenues

# %%
get_eventvenues(soup)
# Out:
# ['XOYO',
#  'Union Club, Vauxhall',
#  'The Cause',
#  'The Roxy',
#  'Spice Of Life',
#  'Chip Shop Brixton',
#  'Egg London',
#  'Corsica Studios',
#  'Ministry Of Sound',
#  'XOYO',
#  'JAKO',
#  'Corsica Studios',
#  'XOYO',
#  'The Roxy',
#  'Chip Shop Brixton',
#  'Union Club, Vauxhall',
#  'Orange Yard',
#  'XOYO',
#  'Egg London',
#  'Folklore',
#  'Iklectik',
#  'Werkhaus',
#  'The Library Lounge at The Standard, London',
#  'New Cross Inn',
#  '100 Wardour Street',
#  'Loop Bar & Nightclub',
#  'Millies Lounge - The Ned',
#  'Egg London',
#  'The Glove That Fits',
#  'DreamBags Jaguarshoes',
#  'Union Club, Vauxhall',
#  'New River Studios',
#  'Omeara',
#  'Pop Brixton',
#  'XOYO',
#  'Camden Assembly',
#  'The Phoenix',
#  'The Barbican Centre',
#  'Shoreditch Platform',
#  "King's Head Members Club",
#  'Basing House',
#  'The Library Lounge at The Standard, London',
#  'Iklectik',
#  'Piccadilly Institute',
#  'Kristin Hjellegjerde Gallery',
#  'Hand of Glory',
#  'Lion and Lamb',
#  'Number 10 London',
#  'Aquum Bar And Restaurant',
#  'Queen Of Hoxton',
#  'Kings Place',
#  '100 Wardour Street',
#  'Moustache Bar',
#  'fabric',
#  'The Jazz Cafe',
#  'The Steel Yard',
#  'XOYO',
#  'Phonox',
#  'Cell 200',
#  'Corsica Studios',
#  'Egg London',
#  'The Pickle Factory',
#  'Village Underground',
#  'Brixton Jamm',
#  'Venue MOT Unit 18',
#  'Lightbox',
#  'The Jazz Cafe',
#  'Camden Assembly',
#  'E1 London',
#  'Night Tales',
#  'Unit 58',
#  'Space 289',
#  'FOLD',
#  'Basing House',
#  'Bermondsey Social Club',
#  'The Waiting Room',
#  'The Cause',
#  'CLF Art Cafe [Block A, Bussey Building]',
#  'Club Storm',
#  'The Fox and Firkin',
#  'Southbank Centre',
#  "NT's",
#  'The Glove That Fits',
#  'Lion and Lamb',
#  'none',
#  'Work Bar',
#  'Five Miles',
#  'XOYO',
#  'Ace Hotel',
#  'Omeara',
#  'CLF Art Lounge & Roof Garden',
#  'Phase',
#  'Trafik',
#  'Habit',
#  'Number 90',
#  'Arcadia Loungebar, Bexleyheath',
#  'Folklore',
#  'Ministry Of Sound',
#  'Shoreditch Platform',
#  'Rye Wax',
#  'Dalston Superstore',
#  'Lockside Camden',
#  'The Prince of Wales',
#  'Cafe OTO',
#  'Beckenham Park Mansion',
#  'Clapham Grand',
#  'Hovarda London',
#  'Fest Camden',
#  'Golden Anchor',
#  'The Four Quarters',
#  'The Magic Garden',
#  'Cafe De Paris',
#  'The Brondes Age',
#  'Revolution',
#  'Revolution',
#  'The Library Lounge at The Standard, London',
#  'Fire Bar',
#  'The Rocksteady',
#  'The Horse & Groom',
#  'Trapeze Basement',
#  'Queen Of Hoxton Rooftop Terrace',
#  'Moustache Bar',
#  'SET',
#  'Notting Hill Arts Club',
#  'The Birds Nest',
#  'Rubys Bar',
#  'Hootananny Brixton',
#  'Red Bar & Restaurant',
#  'none',
#  'none',
#  'Studio 338',
#  'Printworks',
#  'Magazine London',
#  'Electric Brixton',
#  'FOLD',
#  'Basing House',
#  'fabric',
#  'The Pickle Factory',
#  'E1 London',
#  'Canvas',
#  "Mick's Garage",
#  'CLF Art Cafe [Block A, Bussey Building]',
#  '12th Knot Rooftop Bar',
#  'Brixton Jamm',
#  'Electrowerkz',
#  'The Cause',
#  'The Prince of Wales',
#  'Ministry Of Sound',
#  'Corsica Studios',
#  'Night Tales',
#  'The Glove That Fits',
#  'Orange Yard',
#  'Bunker Club',
#  'Spiritland Royal Festival Hall',
#  'The Jazz Cafe',
#  'Off The Cuff',
#  'The Electric Barge',
#  'Phonox',
#  'Oval Space',
#  'Number 90',
#  'Juno Cafe',
#  'The Jago',
#  'Metropolis',
#  'Venue MOT Unit 18',
#  'The Old Baths',
#  'The Red Rooms',
#  'The Waiting Room',
#  'The Spotlight - Broxbourne',
#  'XOYO',
#  'Tola',
#  'Five Miles',
#  'The Jazz Cafe',
#  'The Lighthouse Bar & Club',
#  '93 Feet East',
#  'Lion and Lamb',
#  'Club Reina',
#  'Egg London',
#  'none',
#  'Sugar Hut',
#  'Troxy',
#  'McQueen',
#  'Shoreditch Platform',
#  'Metropolis',
#  'Junction House',
#  'Peckham Audio',
#  'The Book Club',
#  'Queen Of Hoxton',
#  'The Fox and Firkin',
#  'Junction House',
#  'Junction House',
#  'Metropolis',
#  'W Hotel',
#  'Union Club, Vauxhall',
#  'Oslo Hackney',
#  'V-Bar',
#  'CLF Art Lounge & Roof Garden',
#  'Phase',
#  'Arcola Bar',
#  'none',
#  'Proud Cabaret',
#  'Paradise 65 Warehouse',
#  'Club Union',
#  '640east',
#  'The Garage',
#  'Wild Card Brewery',
#  'Dalston Superstore',
#  'The Rocksteady',
#  'Cafe OTO',
#  'The Boston Music Room',
#  'The Horse & Groom',
#  'Green House London',
#  'none',
#  'The Rocksteady',
#  'The Roxy',
#  'The Magic Garden',
#  'Brixton Jamm',
#  'Cafe De Paris',
#  'The Cannick Tapps',
#  'Unit 58',
#  'Beach Blanket Babylon',
#  'Beach Blanket Babylon',
#  'Rye Wax',
#  'Iklectik',
#  'Hootananny Brixton',
#  'The Library Lounge at The Standard, London',
#  "Kadie's Cocktail Bar",
#  'Bloomsbury Bowling Lanes',
#  'Ormside Projects',
#  'none',
#  'Concrete Space',
#  'Roadtrip',
#  'Dalston Den',
#  "King's Head Members Club",
#  'The Gunmakers',
#  'The Vaults',
#  'Brew Club',
#  'Studio 338',
#  '93 Feet East',
#  'fabric',
#  'Village Underground',
#  'Shoreditch Platform',
#  'fabric',
#  'Corsica Studios',
#  'Union Club, Vauxhall',
#  'Werkhaus',
#  'Lion and Lamb',
#  'none',
#  'La Cabina',
#  'Club Reina',
#  'Number 90',
#  'Venue MOT Unit 18',
#  'Brixton Jamm',
#  'Rye Wax']

# %%
allnumattendees = []

for entries in relevantdata.findAll('article'):
    try:
        allnumattendees.append(int(entries.find(class_='attending').text.split()[0]))
                               
    except:
        allnumattendees.append('NA')

# %%
allnumattendees[:5]
# Out:
# [3, 3, 3, 1, 'NA']

# %%
def get_numattendees(soup):
    relevantdata = soup.find('div', class_='fl col4')
    entries = relevantdata.findAll('article')
    numattendees = []
    for entries in relevantdata.findAll('article'):
        try:
            numattendees.append(int(entries.find(class_='attending').text.split()[0]))
        except:
            numattendees.append('NA')
    return numattendees

# %%
get_numattendees(soup)
# Out:
# [3,
#  3,
#  3,
#  1,
#  'NA',
#  'NA',
#  98,
#  57,
#  7,
#  3,
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  14,
#  5,
#  3,
#  2,
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  101,
#  29,
#  18,
#  14,
#  13,
#  11,
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  388,
#  341,
#  296,
#  283,
#  243,
#  213,
#  167,
#  155,
#  140,
#  114,
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  1665,
#  1327,
#  819,
#  585,
#  505,
#  311,
#  277,
#  250,
#  218,
#  213,
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  582,
#  414,
#  384,
#  120,
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA']

# %%
import pandas as pd

def eventscraper(url):
    
    eventnames = []
    eventdates = []
    eventvenues = []
    numattendees = []
    
    html_page = requests.get(url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    
    eventnames += get_eventnames(soup)
    eventdates += get_eventdates(soup)
    eventvenues += get_eventvenues(soup)
    numattendees += get_numattendees(soup)
    
    df = pd.DataFrame([eventnames, eventvenues, eventdates, numattendees]).transpose()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    
    return df

# %%
df = eventscraper('https://www.residentadvisor.net/events')
df
# Out:
#                                 Event_Name                 Venue  Event_Date  \
# 0                 Play London Every Monday                  XOYO  2020-02-24
# 1                     Desire Magic Mondays  Union Club, Vauxhall  2020-02-24
# 2            London DJ School (DJ Lessons)             The Cause  2020-02-24
# 3    Kandy Mondays (£2 Drinks) at The Roxy              The Roxy  2020-02-24
# 4      SCJ! Jam Night and Networking Event         Spice Of Life  2020-02-24
# ..                                     ...                   ...         ...
# 248            Lime - Every Sunday Morning            Club Reina  2020-03-01
# 249     Sunday Selections with Jack Sellen             Number 90  2020-03-01
# 250                           Loose Trax 6     Venue MOT Unit 18  2020-03-01
# 251            Blaffirmative x Kupid - FHP          Brixton Jamm  2020-03-01
# 252                               Monkeys                Rye Wax  2020-03-01
#
#     Number_of_Attendees
# 0                     3
# 1                     3
# 2                     3
# 3                     1
# 4                    NA
# ..                  ...
# 248                  NA
# 249                  NA
# 250                  NA
# 251                  NA
# 252                  NA
#
# [253 rows x 4 columns]

# %%
len(df)
# Out:
# 1000

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
# look for the next page url
nextinfo = soup.find('div', class_= 'page-items content sub clearfix').find('a', attrs = {'ga-event-action':"Next "}).attrs['href']
nextinfo
# Out:
# '/events/uk/london/week/2020-03-02'

# %%
def next_page(url):
    html_page = requests.get(url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    exturl = soup.find('div', class_= 'page-items content sub clearfix').find('a', attrs = {'ga-event-action':"Next "}).attrs['href']
    next_page_url = "https://www.residentadvisor.net" + exturl
    return next_page_url

# %%
next_page('https://www.residentadvisor.net/events/uk/london/week/2020-03-02')
# Out:
# 'https://www.residentadvisor.net/events/uk/london/week/2020-03-09'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here
rows = 0
url = "https://www.residentadvisor.net/events"
dfs = []

while rows <= 1000:
    df = eventscraper(url)#run the event scrapper function and save into df
    dfs.append(df)
    rows += len(df)
    url = next_page(url)

df = pd.concat(dfs)

# %%
df[:1000]
# Out:
#                                            Event_Name                 Venue  \
# 0                            Play London Every Monday                  XOYO
# 1                                Desire Magic Mondays  Union Club, Vauxhall
# 2                       London DJ School (DJ Lessons)             The Cause
# 3               Kandy Mondays (£2 Drinks) at The Roxy              The Roxy
# 4                 SCJ! Jam Night and Networking Event         Spice Of Life
# ..                                                ...                   ...
# 23                                      Giolì & Assia         The Jazz Cafe
# 24                                            Rupture       Corsica Studios
# 25                           Unleash presents Solomun            Printworks
# 26                             Spencer Brown - London        Colours Hoxton
# 27  RE-TEXTURED — Dbridge presents Black Electric,...   Village Underground
#
#     Event_Date Number_of_Attendees
# 0   2020-02-24                   3
# 1   2020-02-24                   3
# 2   2020-02-24                   3
# 3   2020-02-24                   1
# 4   2020-02-24                  NA
# ..         ...                 ...
# 23  2020-04-03                 217
# 24  2020-04-03                 200
# 25  2020-04-03                 195
# 26  2020-04-03                 150
# 27  2020-04-03                 126
#
# [1000 rows x 4 columns]

# %%
#choose to replace NA for attendees by 0
df['Number_of_Attendees'] = df['Number_of_Attendees'].replace('NA', int(0))

# %%
df.head(10)
# Out:
#                               Event_Name                 Venue  Event_Date  \
# 0               Play London Every Monday                  XOYO  2020-02-24
# 1                   Desire Magic Mondays  Union Club, Vauxhall  2020-02-24
# 2          London DJ School (DJ Lessons)             The Cause  2020-02-24
# 3  Kandy Mondays (£2 Drinks) at The Roxy              The Roxy  2020-02-24
# 4    SCJ! Jam Night and Networking Event         Spice Of Life  2020-02-24
# 5                         Mobile Mondays     Chip Shop Brixton  2020-02-24
# 6       Paradox presents Tuesday Madness            Egg London  2020-02-25
# 7                   Synergy: Back 2 Back       Corsica Studios  2020-02-25
# 8      Pancake Rave at Ministry of Sound     Ministry Of Sound  2020-02-25
# 9               Play London Every Monday                  XOYO  2020-02-25
#
#    Number_of_Attendees
# 0                    3
# 1                    3
# 2                    3
# 3                    1
# 4                    0
# 5                    0
# 6                   98
# 7                   58
# 8                    7
# 9                    3

# %%
df = df.sort_values('Number_of_Attendees', ascending = False)

# %%
df
# Out:
#                                             Event_Name                Venue  \
# 130                     Space Ibiza 2020 Opening Party           Studio 338
# 57   RE-TEXTURED — British Murder Boys (Live), Hele...         Tobacco Dock
# 131                                               ANTS           Printworks
# 17                                         RE-TEXTURED                 none
# 95   Honey Dijon Pres. 'Black Girl Magic' with BBZ ...  Village Underground
# ..                                                 ...                  ...
# 151    Des Was a Bowie Fan: Walthamstow - The Chequers         The Chequers
# 152                                              Faded       Junction House
# 153                                          Tarabband             Rich Mix
# 154                                         Glitterbox           Printworks
# 114                       Jack Priest at The Ace Hotel            Ace Hotel
#
#      Event_Date  Number_of_Attendees
# 130  2020-02-29                 1668
# 57   2020-04-04                 1544
# 131  2020-02-29                 1327
# 17   2020-04-02                 1166
# 95   2020-03-07                 1127
# ..          ...                  ...
# 151  2020-03-07                    0
# 152  2020-03-07                    0
# 153  2020-03-07                    0
# 154  2020-03-07                    0
# 114  2020-04-05                    0
#
# [1087 rows x 4 columns]

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
